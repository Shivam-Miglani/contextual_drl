# %%
import pickle

# %%
import multiprocessing

from gensim.models import Word2Vec

# %%
cores = multiprocessing.cpu_count()
print(cores)
# Out:
# 4

# %%
pickle_in = open("wikihow.pickle","rb")
sentences = pickle.load(pickle_in)
print(sentences)
# Out:
# [['Throw|VB', 'away|RP', 'or|CC', 'recycle|VB', 'alkaline|JJ', 'batteries|NNS'], ['Alkaline|NNP', 'batteries|NNS', 'are|VBP', 'the|DT', 'type|NN', 'that|WDT', 'power|NN', 'most|RBS', 'simple|JJ', 'battery-operated|JJ', 'devices|NNS', 'such|JJ', 'as|IN', 'flashlights|NNS', 'toys|IN', 'remote|JJ', 'controls|NNS', 'or|CC', 'smoke|NN', 'alarms|NNS'], ['They|PRP', 'come|VBP', 'in|IN', 'a|DT', 'variety|NN', 'of|IN', 'sizes|NNS', 'ranging|VBG', 'from|IN', 'AAA|NNP', 'to|TO', '9|CD', 'volt|NNS'], ['Proper|NNP', 'disposal|NN', 'methods|NNS', 'for|IN', 'alkaline|JJ', 'batteries|NNS', 'may|MD', 'depend|VB', 'on|IN', 'your|PRP$', 'local|JJ', 'waste|NN', 'regulations|NNS'], ['Most|JJS', 'alkaline|JJ', 'batteries|NNS', 'manufactured|VBD', 'since|IN', '1996|CD', 'are|VBP', 'made|VBN', 'of|IN', 'relatively|RB', 'non-hazardous|JJ', 'materials|NNS', 'and|CC', 'can|MD', 'be|VB', 'tossed|VBN', 'directly|RB', 'into|IN', 'the|DT', 'trash|NN'], ['However|RB', 'some|DT', 'states|NNS', 'or|CC', 'municipalities|NNS', 'still|RB', 'require|VBP', 'that|IN', 'alkaline|NN', 'batteries|NNS', 'be|VB', 'treated|VBN', 'as|IN', 'hazardous|JJ', 'waste|NN'], ['In|IN', 'these|DT', 'cases|NNS', 'the|DT', 'batteries|NNS', 'must|MD', 'be|VB', 'recycled|VBN', 'or|CC', 'dropped|VBN', 'off|RP', 'at|IN', 'a|DT', 'designated|JJ', 'facility|NN'], ['You|PRP', 'may|MD', 'be|VB', 'able|JJ', 'to|TO', 'drop|VB', 'off|RP', 'alkaline|JJ', 'batteries|NNS', 'for|IN', 'recycling|VBG', 'at|IN', 'a|DT', 'local|JJ', 'electronics|NNS', 'retailer|VBP', 'recycling|VBG', 'center|NN', 'or|CC', 'community|NN', 'center|NN'], ['Check|VB', 'the|DT', 'Earth911|NNP', 'website|NN', 'for|IN', 'drop-off|JJ', 'locations|NNS', 'in|IN', 'your|PRP$', 'area|NN'], ['Dispose|NNP', 'of|IN', 'car|NN', 'batteries|NNS', 'at|IN', 'an|DT', 'auto|NN', 'parts|NNS', 'retailer|NN', 'or|CC', 'hazardous|JJ', 'waste|NN', 'collection|NN', 'site|NN'], ['Since|IN', 'car|NN', 'batteries|NNS', 'contain|VBP', 'lead|JJ', 'acid|IN', 'they|PRP', 'can’t|VBP', 'be|VB', 'disposed|VBN', 'of|IN', 'in|IN', 'the|DT', 'trash|NN', 'or|CC', 'tossed|VBN', 'in|IN', 'with|IN', 'your|PRP$', 'recycling|VBG'], ['Many|JJ', 'retailers|NNS', 'like|IN', 'Home|NNP', 'Depot|NNP', 'or|CC', 'Auto|NNP', 'Zone|NNP', 'will|MD', 'accept|VB', 'dead|JJ', 'or|CC', 'used|JJ', 'car|NN', 'batteries|NNS'], ['You|PRP', 'can|MD', 'also|RB', 'drop|VB', 'them|PRP', 'off|RP', 'at|IN', 'recycling|VBG', 'or|CC', 'waste|NN', 'disposal|NN', 'facilities|NNS', 'that|WDT', 'specialize|VBP', 'in|IN', 'hazardous|JJ', 'materials|NNS'], ['Take|NNP', 'rechargeable|JJ', 'batteries|NNS', 'to|TO', 'a|DT', 'recycling|NN', 'facility|NN'], ['Rechargeable|JJ', 'batteries|NNS', 'contain|VBP', 'nickel|JJ', 'and|CC', 'cadmium|NN', 'which|WDT', 'can|MD', 'create|VB', 'an|DT', 'environmental|JJ', 'hazard|NN', 'if|IN', 'the|DT', 'batteries|NNS', 'are|VBP', 'thrown|VBN', 'away|RB', 'in|IN', 'a|DT', 'landfill|NN', 'or|CC', 'an|DT', 'incinerator|NN'], ['These|DT', 'batteries|NNS', 'must|MD', 'be|VB', 'disposed|VBN', 'of|IN', 'at|IN', 'a|DT', 'hazardous|JJ', 'waste|NN', 'collection|NN', 'site|NN', 'recycling|VBG', 'facility|NN', 'or|CC', 'an|DT', 'electronics|NNS', 'retailer|NN', 'that|IN', 'recycles|VBZ', 'batteries|NNS'], ['Many|JJ', 'electronics|NNS', 'retailers|NNS', 'like|IN', 'Radio|NNP', 'Shack|NNP', 'or|CC', 'Staples|NNP', 'will|MD', 'accept|VB', 'used|VBN', 'rechargeable|JJ', 'batteries|NNS', 'for|IN', 'recycling|VBG'], ['Check|NNP', 'Earth911com|NNP', 'for|IN', 'participating|VBG', 'retailers|NNS', 'in|IN', 'your|PRP$', 'area|NN'], ['Donate|NNP', 'or|CC', 'recycle|VB', 'lithium-ion|NN', 'batteries|NNS'], ['These|DT', 'are|VBP', 'the|DT', 'kinds|NNS', 'of|IN', 'batteries|NNS', 'that|WDT', 'typically|RB', 'power|NN', 'portable|JJ', 'electronics|NNS', 'like|IN', 'your|PRP$', 'mobile|JJ', 'phone|NN', 'digital|JJ', 'camera|NN', 'tablet|NN', 'or|CC', 'laptop|VB'], ['Lithium-ion|JJ', 'batteries|NNS', 'can|MD', 'be|VB', 'recycled|VBN', 'at|IN', 'a|DT', 'recycling|VBG', 'center|NN', 'or|CC', 'ha ...

# %%
w2v_model = Word2Vec(
                     size=50,
                     sample=6e-5, 
                     alpha=0.03, 
                     min_alpha=0.0007, 
                     negative=20,
                     workers=cores-1)

# %%
w2v_model.build_vocab(sentences, progress_per=100)

# %%
words = list(w2v_model.wv.vocab)
print(words)
# Out:
# ['Throw|VB', 'away|RP', 'or|CC', 'alkaline|JJ', 'batteries|NNS', 'are|VBP', 'the|DT', 'type|NN', 'that|WDT', 'power|NN', 'most|RBS', 'simple|JJ', 'devices|NNS', 'such|JJ', 'as|IN', 'smoke|NN', 'They|PRP', 'come|VBP', 'in|IN', 'a|DT', 'variety|NN', 'of|IN', 'sizes|NNS', 'from|IN', 'to|TO', 'methods|NNS', 'for|IN', 'may|MD', 'on|IN', 'your|PRP$', 'local|JJ', 'waste|NN', 'Most|JJS', 'since|IN', 'made|VBN', 'relatively|RB', 'materials|NNS', 'and|CC', 'can|MD', 'be|VB', 'directly|RB', 'into|IN', 'trash|NN', 'However|RB', 'some|DT', 'still|RB', 'require|VBP', 'that|IN', 'treated|VBN', 'hazardous|JJ', 'In|IN', 'these|DT', 'cases|NNS', 'must|MD', 'off|RP', 'at|IN', 'You|PRP', 'able|JJ', 'drop|VB', 'recycling|VBG', 'electronics|NNS', 'center|NN', 'Check|VB', 'area|NN', 'car|NN', 'an|DT', 'parts|NNS', 'collection|NN', 'site|NN', 'contain|VBP', 'they|PRP', 'can’t|VBP', 'with|IN', 'Many|JJ', 'retailers|NNS', 'like|IN', 'will|MD', 'dead|JJ', 'also|RB', 'them|PRP', 'Take|NNP', 'which|WDT', 'create|VB', 'if|IN', 'away|RB', 'These|DT', 'used|VBN', 'Check|NNP', 'typically|RB', 'portable|JJ', 'phone|NN', 'program|NN', 'The|DT', 'other|JJ', 'list|NN', 'here|RB', 'find|VB', 'out|RP', 'This|DT', 'kind|NN', 'is|VBZ', 'household|NN', 'proper|JJ', 'extremely|RB', 'should|MD', 'never|RB', 'books|NNS', 'don’t|VBP', 'all|DT', 'have|VBP', 'lined|VBN', 'up|RP', 'along|IN', 'shelf|NN', 'Create|VB', 'stack|NN', 'two|CD', 'three|CD', 'place|NN', 'it|PRP', 'beside|IN', 'serve|VB', 'hold|VB', 'others|NNS', 'Use|NNP', 'tables|NNS', 'Place|NN', 'small|JJ', 'side|NN', 'table|NN', 'coffee|NN', 'Then|RB', 'put|VBD', 'lamp|NN', 'top|NN', 'how|WRB', 'many|JJ', 'until|IN', 'you|PRP', 'find|VBP', 'level|NN', 'best|JJS', 'Find|NNP', 'large|JJ', 'use|VB', 'Look|NN', 'old|JJ', 'Put|VB', 'tray|NN', 'vase|NN', 'flowers|NNS', 'interesting|JJ', 'object|NN', 'vintage|NN', 'glass|NN', 'same|JJ', 'color|NN', 'scheme|NN', 'line|NN', 'For|IN', 'example|NN', 'shades|NNS', 'blue|NN', 'choose|VB', 'different|JJ', 'neutral|JJ', 'look|NN', 'Or|CC', 'remove|VB', 'covers|NNS', 'get|VB', 'have|VB', 'white|JJ', 'spine|NN', 'paint|NN', 'If|IN', 'want|VBP', 'match|VB', 'each|DT', 'decor|NN', 'lightly|RB', 'then|RB', 'hang|VB', 'dry|VB', 'wallpaper|NN', 'material|NN', 'inside|NN', 'cover|NN', 'theme|NN', 'room|NN', 'decorate|VB', 'nursery|NN', 'gardening|NN', 'sun|NN', 'lots|NNS', 'plants|NNS', 'search|NN', 'pages|NNS', 'book|NN', 'that’s|NN', 'falling|VBG', 'just|RB', 'one|CD', 'look|VB', 'separate|VB', 'completely|RB', 'leave|VB', 'intact|JJ', 'Wrap|NNP', 'around|IN', 'display|VB', 'this|DT', 'little|JJ', 'add|VB', 'dried|JJ', 'flower|NN', 'more|JJR', 'style|NN', 'separate|JJ', 'containers|NNS', 'food|NN', 'water|NN', 'colors|NNS', 'Use|VB', 'bowl|NN', 'put|VB', 'ice|NN', 'towels|NNS', 'protect|VB', 'work|NN', 'surface|NN', 'Dip|NNP', 'brush|VB', 'paper|NN', 'apply|VB', 'about|IN', 'towel|NN', 'least|JJS', 'square|NN', 'any|DT', 'excess|JJ', 'back|RB', 'container|NN', 'Don’t|NNP', 'too|RB', 'very|RB', 'long|RB', 'colored|VBN', 'areas|NNS', 'great|JJ', 'good|JJ', 'time|NN', 'while|IN', 'children|NNS', 'Lay|NNP', 'out|IN', 'driveway|NN', 'Let|VB', 'sit|VB', 'dry|JJ', 'touch|NN', 'want|VB', 'over|RP', 'once|RB', 'drying|VBG', 'help|VB', 'dry|VBP', 'day|NN', 'either|CC', 'indoors|NNS', 'make|VB', 'sure|JJ', 'corners|NNS', 'down|RP', 'middle|NN', 'cleaner|NN', 'together|RB', 'cleaner|JJR', 'couple|NN', 'times|NNS', 'gently|RB', 'hands|NNS', 'before|IN', 'edge|NN', 'form|VB', 'thin|JJ', 'rectangle|NN', 'over|IN', 'onto|IN', 'itself|PRP', 'again|RB', 'it’s|JJ', 'Make|NNP', 'simply|RB', 'ends|NNS', 'Attach|NNP', 'secure|VB', 'tape|NN', 'hot|JJ', 'glue|NN', 'further|RB', 'Add|NNP', 'stickers|NNS', 'eyes|NNS', 'eye|NN', 'whatever|WDT', 'decorations|NNS', 'like|VBP', 'colorful|JJ', 'bit|NN', 'sure|NN', 'instructions|NNS', 'safety|NN', 'precautions|NNS', 'when|WRB', 'using|VBG', 'ceiling|NN', 'string|NN', 'board|NN', 'Paint|VB', 'canisters|NNS', 'purchase|VB', 'choice|NN', 'matches|VBZ', 'kitchen|NN',  ...

# %%
w2v_model.train(sentences, total_examples=w2v_model.corpus_count, epochs=100, report_delay=1)
# Out:
# (1662464, 6257600)

# %%
print(w2v_model['table|NN'])
# Out:
# [-0.8931337  -0.43355232  0.9706589  -0.69724435 -0.35685667  0.6449287
#   0.2351504   0.4722906   0.6342371  -0.38989955  0.44885066 -0.17987725
#  -0.48544595  1.2197899   0.20406488 -0.19699785 -0.76124626  0.00891995
#  -0.61053455 -0.26431265  0.67753506 -0.4206011   0.3240589   1.5284727
#  -1.2323694   0.62267995 -0.01254285  0.2456657   0.8266868   0.2887746
#   0.6142253   0.8280714   0.22758311 -0.6106867  -0.7514974   0.4594305
#   0.37911907  0.34777862 -0.93313944  0.54378045 -0.8366597  -0.64492726
#  -0.39678484  0.76335925  0.8581378  -1.3947296  -0.25917086 -0.41245863
#   0.46685678 -1.8100003 ]
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
w2v_model.init_sims(replace=True)

# %%
w2v_model.wv.most_similar(positive=['table|NN'])
# Out:
# [('side|NN', 0.8157789707183838),
#  ('runner|NN', 0.7931182384490967),
#  ('beside|IN', 0.7869718074798584),
#  ('lined|VBN', 0.7664886116981506),
#  ('tables|NNS', 0.7612799406051636),
#  ('stack|NN', 0.7611902356147766),
#  ('macrame|NN', 0.7467726469039917),
#  ('shelf|NN', 0.7425206303596497),
#  ('empty|JJ', 0.7313172817230225),
#  ('chair|NN', 0.7237756252288818)]

# %%
w2v_model.wv.save_word2vec_format('cooking.txt', binary=False)

# %%
new_model = Word2Vec.load('cooking.bin')

# %%
print(new_model)
import gensim
# Out:
# Word2Vec(vocab=753, size=50, alpha=0.03)

# %%
import gensim
word_vectors = gensim.models.KeyedVectors.load_word2vec_format('cooking.txt', binary=False)

# %%
word_vectors.save('cooking.gensim')

# %%
def tsne_plot(model):
    "Creates and TSNE model and plots it"
    labels = []
    tokens = []

    for word in model.wv.vocab:
        tokens.append(model[word])
        labels.append(word)
    
    tsne_model = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
    new_values = tsne_model.fit_transform(tokens)

    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])
        
    plt.figure(figsize=(16, 16)) 
    for i in range(len(x)):
        plt.scatter(x[i],y[i])
        plt.annotate(labels[i],
                     xy=(x[i], y[i]),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
    plt.show()

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
# %matplotlib inline
tsne_plot(word_vectors)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).

# %%
word_vectors2 = gensim.models.KeyedVectors.load_word2vec_format('data/mymodel-new-5-50', binary=True)
#tsne_plot(word_vectors2)

# %%
word_vectors.most_similar('Preheat|NNP')
# Out:
# [('oven|PRP', 0.7154855728149414),
#  ('degree|NN', 0.5448174476623535),
#  ('350|CD', 0.537542462348938),
#  ('Preheat|VB', 0.5115108489990234),
#  ('375|CD', 0.5007966160774231),
#  ('F|NNP', 0.49891939759254456),
#  ('degrees|NNS', 0.47930875420570374),
#  ('425|CD', 0.46077388525009155),
#  ('high|JJ', 0.4595765471458435),
#  ('grill|NN', 0.39197444915771484)]

# %%
word_vectors2.most_similar('Preheat')
# Out:
# [('Pre-heat', 0.943618655204773),
#  ('Defrost', 0.8425519466400146),
#  ('Roast', 0.8083687424659729),
#  ('350ºF', 0.7805397510528564),
#  ('Marinate', 0.7757312059402466),
#  ('Roasting', 0.7743902206420898),
#  ('preheat', 0.7708082795143127),
#  ('(176ºC)', 0.7646396160125732),
#  ('Broil', 0.7632626295089722),
#  ('Toasting', 0.7587652802467346)]

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
# %matplotlib inline
tsne_plot(word_vectors2)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(style="white")

# Generate a large random dataset
corr = np.load("cos_sim_cs.npy")
corr = corr[:20,:20]
print(corr)

# Compute the correlation matrix

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
print(mask)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(240,10,n=9,as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# [[0.99999976 0.99999976 0.69056845 0.99999976 0.69056845 0.61056906
#   0.99999976 0.69056845 0.61056906 0.5966819  0.99999976 0.69056845
#   0.61056906 0.5966819  0.69509894 0.99999976 0.69056845 0.61056906
#   0.5966819  0.69509894]
#  [0.99999976 0.99999976 0.69056845 0.99999976 0.69056845 0.61056906
#   0.99999976 0.69056845 0.61056906 0.5966819  0.99999976 0.69056845
#   0.61056906 0.5966819  0.69509894 0.99999976 0.69056845 0.61056906
#   0.5966819  0.69509894]
#  [0.69056845 0.69056845 0.9999998  0.69056845 0.9999998  0.7724738
#   0.69056845 0.9999998  0.7724738  0.6306365  0.69056845 0.9999998
#   0.7724738  0.6306365  0.80366015 0.69056845 0.9999998  0.7724738
#   0.6306365  0.80366015]
#  [0.99999976 0.99999976 0.69056845 0.99999976 0.69056845 0.61056906
#   0.99999976 0.69056845 0.61056906 0.5966819  0.99999976 0.69056845
#   0.61056906 0.5966819  0.69509894 0.99999976 0.69056845 0.61056906
#   0.5966819  0.69509894]
#  [0.69056845 0.69056845 0.9999998  0.69056845 0.9999998  0.7724738
#   0.69056845 0.9999998  0.7724738  0.6306365  0.69056845 0.9999998
#   0.7724738  0.6306365  0.80366015 0.69056845 0.9999998  0.7724738
#   0.6306365  0.80366015]
#  [0.61056906 0.61056906 0.7724738  0.61056906 0.7724738  0.9999993
#   0.61056906 0.7724738  0.9999993  0.771317   0.61056906 0.7724738
#   0.9999993  0.771317   0.8025828  0.61056906 0.7724738  0.9999993
#   0.771317   0.8025828 ]
#  [0.99999976 0.99999976 0.69056845 0.99999976 0.69056845 0.61056906
#   0.99999976 0.69056845 0.61056906 0.5966819  0.99999976 0.69056845
#   0.61056906 0.5966819  0.69509894 0.99999976 0.69056845 0.61056906
#   0.5966819  0.69509894]
#  [0.69056845 0.69056845 0.9999998  0.69056845 0.9999998  0.7724738
#   0.69056845 0.9999998  0.7724738  0.6306365  0.69056845 0.9999998
#   0.7724738  0.6306365  0.80366015 0.69056845 0.9999998  0.7724738
#   0.6306365  0.80366015]
#  [0.61056906 0.61056906 0.7724738  0.61056906 0.7724738  0.9999993
#   0.61056906 0.7724738  0.9999993  0.771317   0.61056906 0.7724738
#   0.9999993  0.771317   0.8025828  0.61056906 0.7724738  0.9999993
#   0.771317   0.8025828 ]
#  [0.5966819  0.5966819  0.6306365  0.5966819  0.6306365  0.771317
#   0.5966819  0.6306365  0.771317   0.99999994 0.5966819  0.6306365
#   0.771317   0.99999994 0.7243937  0.5966819  0.6306365  0.771317
#   0.99999994 0.7243937 ]
#  [0.99999976 0.99999976 0.69056845 0.99999976 0.69056845 0.61056906
#   0.99999976 0.69056845 0.61056906 0.5966819  0.99999976 0.69056845
#   0.61056906 0.5966819  0.69509894 0.99999976 0.69056845 0.61056906
#   0.5966819  0.69509894]
#  [0.69056845 0.69056845 0.9999998  0.69056845 0.9999998  0.7724738
#   0.69056845 0.9999998  0.7724738  0.6306365  0.69056845 0.9999998
#   0.7724738  0.6306365  0.80366015 0.69056845 0.9999998  0.7724738
#   0.6306365  0.80366015]
#  [0.61056906 0.61056906 0.7724738  0.61056906 0.7724738  0.9999993
#   0.61056906 0.7724738  0.9999993  0.771317   0.61056906 0.7724738
#   0.9999993  0.771317   0.8025828  0.61056906 0.7724738  0.9999993
#   0.771317   0.8025828 ]
#  [0.5966819  0.5966819  0.6306365  0.5966819  0.6306365  0.771317
#   0.5966819  0.6306365  0.771317   0.99999994 0.5966819  0.6306365
#   0.771317   0.99999994 0.7243937  0.5966819  0.6306365  0.771317
#   0.99999994 0.7243937 ]
#  [0.69509894 0.69509894 0.80366015 0.69509894 0.80366015 0.8025828
#   0.69509894 0.80366015 0.8025828  0.7243937  0.69509894 0.80366015
#   0.8025828  0.7243937  1.         0.69509894 0.80366015 0.8025828
#   0.7243937  1.        ]
#  [0.99999976 0.99999976 0.69056845 0.99999976 0.69056845 0.61056906
#   0.99999976 0.69056845 0.61056906 0.5966819  0.99999976 0.69056845
#   0.61056906 0.5966819  0.69509894 0.99999976 0.69056845 0.61056906
#   0.5966819  0.69509894]
#  [0.69056845 0.69056845 0.9999998  0.69056845 0.9999998  0.7724738
#   0.69056845 0.9999998  0.7724738  0.6306365  0.69056845 0.9999998
#   0.7724738  0.6306365  0.80366015 0.69056845 0.9999998  0.7724738
#   0.6306365  0.80366015]
#  [0.61056906 0.61056906 0.7724738  0.61056906 0.7724738  0.9999993
#   0.61056906 0.7724738  0.9999993  0.771317   0.61056906 0.7724738
#   0.9999993  0.771317   0.8025828  0.61056906 0.7724738  0.9999993
#   0.771317   0.8025828 ]
#  [0.5966819  0.5966819  0.6306365  0.5966819  0.6306365  0.771317
#   0.5966819  0.6306365  0.771317   0.99999994 0.5966819  0.6306365
#   0.771317   0.99999994 0.7243937  0.5966819  0.6306365  0.771317
#   0.99999994 0.7243937 ]
#  [0.69509894 0.69509894 0.80366015 0.69509894 0.80366015 0.8025828
#   0.69509894 0.80366015 0.8025828  0.7243937  0.69509894 0.80366015
#   0.8025828  0.7243937  1.         0.69509894 0.80366015 0.8025828
#   0.7243937  1.        ]]
# [[ True  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True]
#  [False  True  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True]
#  [False False  True  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True]
#  [False False False  True  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True]
#  [False False False False  True  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True]
#  [False False False False False  True  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True]
#  [False False False False False False  True  True  True  True  True  True
#    True  True  True  True  True  True  True  True]
#  [False False False False False False False  True  True  True  True  True
#    True  True  True  True  True  True  True  True]
#  [False False False False False False False False  True  True  True  True
#    True  True  True  True  True  True  True  True]
#  [False False False False False False False False False  True  True  True
#    True  True  True  True  True  True  True  True]
#  [False False False False False False False False False False  True  True
#    True  True  True  True  True  True  True  True]
#  [False False False False False False False False False False False  True
#    True  True  True  True  True  True  True  True]
#  [False False False False False False False False False False False False
#    True  True  True  True  True  True  True  True]
#  [False False False False False False False False False False False False
#   False  True  True  True  True  True  True  True]
#  [False False False False False False False False False False False False
#   False False  True  True  True  True  True  True]
#  [False False False False False False False False False False False False
#   False False False  True  True  True  True  True]
#  [False False False False False False False False False False False False
#   False False False False  True  True  True  True]
#  [False False False False False False False False False False False False
#   False False False False False  True  True  True]
#  [False False False False False False False False False False False False
#   False False False False False False  True  True]
#  [False False False False False False False False False False False False
#   False False False False False False False  True]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-d1b181f5532a> in <module>()
#      23
#      24 # Generate a custom diverging colormap
# ---> 25 cmap = sns.diverging_palette(as_cmap=True)
#      26
#      27 # Draw the heatmap with the mask and correct aspect ratio
#
# TypeError: diverging_palette() missing 2 required positional arguments: 'h_neg' and 'h_pos'
